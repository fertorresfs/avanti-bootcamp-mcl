# %% [markdown]
# # Análise exploratória de dados

# %% [markdown]
# ## 1. Download do Dataset

# %%
# !pip install opendatasets
# !pip install pandas
# !pip install imagehash
# Out:
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.10/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.6)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.6.17)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.32.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: imagehash in /usr/local/lib/python3.10/dist-packages (4.3.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash) (1.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imagehash) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash) (11.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imagehash) (1.13.1)

# %%
import opendatasets as od
import pandas
import cv2
import os
import pandas as pd
import imagehash
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
# %matplotlib inline

palette = sns.color_palette("pastel")
sns.set_style("whitegrid")
sns.set_theme(style="ticks")
sns.set_palette(sns.color_palette(palette))

# %%
od.download("https://www.kaggle.com/datasets/alistairking/recyclable-and-household-waste-classification")
# Out:
# Skipping, found downloaded files in "./recyclable-and-household-waste-classification" (use force=True to force download)

# %%
# !ls
# Out:
# recyclable-and-household-waste-classification  sample_data

# %% [markdown]
# ### 1.2. Descrição dos dados
#
# ![residuos_reciclaveis.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Estrutura do conjunto de dados**
#
# O conjunto de dados é organizado em uma estrutura de pasta hierárquica para garantir fácil navegação e acessibilidade. A pasta principal, chamada "imagens", contém subpastas que representam categorias ou itens específicos de resíduos. Esses nomes de subpastas servem como rótulos para suas respectivas categorias, tornando conveniente para pesquisadores e desenvolvedores identificar e utilizar as imagens para suas necessidades específicas.
#
# Dentro de cada subpasta de categoria, há duas pastas distintas:
#
# 1. default: Esta pasta contém imagens padrão ou de estúdio do item de resíduo. Essas imagens fornecem uma representação clara e controlada do item, o que pode ser útil para treinamento inicial e teste de modelos de classificação de resíduo. Cada subpasta "padrão" contém 250 imagens.
# 2. real_world: Esta pasta contém imagens do item de resíduo em cenários ou ambientes do mundo real. Essas imagens capturam o item em vários contextos, como em uma lata de lixo, no chão ou em um ambiente desorganizado. As imagens do mundo real são essenciais para avaliar o desempenho e a robustez dos modelos de classificação de resíduos em ambientes práticos. Cada subpasta "real_world" também contém 250 imagens.
#
# Todas as imagens no conjunto de dados são fornecidas no **formato PNG**, garantindo alta qualidade e compatibilidade com uma ampla variedade de bibliotecas de processamento de imagens e aprendizado de máquina. O ```Recyclable and Household Waste Classification Dataset``` oferece uma ampla gama de possibilidades para pesquisadores, engenheiros e entusiastas ambientais. Alguns usos e aplicações potenciais deste conjunto de dados incluem:
#
# - Desenvolvendo e treinando modelos de machine learning para classificação e categorização automática de resíduos;
# - Analise das características visuais e recursos de diferentes materiais residuais;
# - Comparação o desempenho de algoritmos de classificação de resíduos em imagens padrão e do mundo real;
# - Investigar o impacto de cenários do mundo real na precisão do reconhecimento de resíduos.

# %% [markdown]
# ## 2. Dataframe com os metadados das imagens

# %%
count_corrupted = 0
corrupted = list()

# %%
root_dir = './recyclable-and-household-waste-classification/images/images'

all_images = []

# Percorrer os diretórios e subdiretórios de imagens
for folders in os.listdir(root_dir):
    child_dir = os.path.join(root_dir, folders)
    if os.path.isdir(child_dir):
        for sub_dir in ['default', 'real_world']:
            sub_dir_path = os.path.join(child_dir, sub_dir)
            if os.path.isdir(sub_dir_path):
                for image in os.listdir(sub_dir_path):
                    img_dir = os.path.join(sub_dir_path, image)
                    if img_dir.endswith(('.jpg', '.png')):
                        img = cv2.imread(img_dir)
                        if img is not None:
                            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                            img_pil = Image.fromarray(img_rgb)
                            img_hash = imagehash.phash(img_pil)
                            width, height, channels = img.shape
                            img_corrupted = False
                        else:
                            count_corrupted += 1
                            corrupted.append(img_dir)
                            img_corrupted = True
                            img_hash, width, height, channels = None, None, None, None

                        all_images.append([img_dir, img_corrupted, str(img_hash), image.split('.')[-1], width, height, channels, folders])

# %%
print(f'Total de Imagens Corrompidas: {count_corrupted}\nImagens corrompidas {corrupted}')
# Out:
# Total de Imagens Corrompidas: 0
# Imagens corrompidas []

# %%
df = pd.DataFrame(all_images, columns=['image_path', 'corrupted', 'image_hash', 'image_format', 'width', 'height', 'channels', 'label'])
df
# Out:
#                                               image_path  corrupted  \
# 0      ./recyclable-and-household-waste-classificatio...      False
# 1      ./recyclable-and-household-waste-classificatio...      False
# 2      ./recyclable-and-household-waste-classificatio...      False
# 3      ./recyclable-and-household-waste-classificatio...      False
# 4      ./recyclable-and-household-waste-classificatio...      False
# ...                                                  ...        ...
# 14995  ./recyclable-and-household-waste-classificatio...      False
# 14996  ./recyclable-and-household-waste-classificatio...      False
# 14997  ./recyclable-and-household-waste-classificatio...      False
# 14998  ./recyclable-and-household-waste-classificatio...      False
# 14999  ./recyclable-and-household-waste-classificatio...      False
#
#              image_hash image_format  width  height  channels  \
# 0      807d3ba66689d387          png    256     256         3
# 1      bf99f84685611bc2          png    256     256         3
# 2      af8e2d31cc09732d          png    256     256         3
# 3      d2fc6d91748901ee          png    256     256         3
# 4      fbc2d42aad259455          png    256     256         3
# ...                 ...          ...    ...     ...       ...
# 14995  bed89491d62fc303          png    256     256         3
# 14996  c5f3a009dba6079b          png    256     256         3
# 14997  851feaf0f081b85e          png    256     256         3
# 14998  ee8791704a8d3fe0          png    256     256         3
# 14999  c8e8bf27945e4368          png    256     256         3
#
#                        label
# 0      plastic_shopping_bags
# 1      plastic_shopping_bags
# 2      plastic_shopping_bags
# 3      plastic_shopping_bags
# 4      plastic_shopping_bags
# ...                      ...
# 14995        steel_food_cans
# 14996        steel_food_cans
# 14997        steel_food_cans
# 14998        steel_food_cans
# 14999        steel_food_cans
#
# [15000 rows x 8 columns]

# %% [markdown]
# ## 3. Verificar a Integridade dos Arquivos

# %%
#Informações estatísticas dos valores de altura, largura e canais das imagens
df.describe().loc[['mean', 'std', 'min', 'max']]
# Out:
#       width  height  channels
# mean  256.0   256.0       3.0
# std     0.0     0.0       0.0
# min   256.0   256.0       3.0
# max   256.0   256.0       3.0

# %%
df['image_format'].value_counts().plot(
    kind='bar',
    title='Número de Imagens por Formato',
)
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## 4. Verificar a Consistência dos Metadados

# %%
#Distribuição das Dimensões de Altura e Largura das Imagens

plt.scatter(df['width'], df['height'])

# %% [markdown]
# Este Dataset contêm uma coleção de 15.00 imagens e todas elas tem 256x256 pixels.

# %%
#Quantidade de informações nulas
df.isnull().sum()
# Out:
# image_path      0
# corrupted       0
# image_hash      0
# image_format    0
# width           0
# height          0
# channels        0
# label           0
# dtype: int64

# %% [markdown]
# ## 5. Analisar a Qualidade das Imagens

# %%
#Total de imagens corrompidas

df['corrupted'].sum()
# Out:
# 0

# %% [markdown]
# ## 6. Verificar a Distribuição das Classes

# %%
total_images = sorted(os.listdir(root_dir))

objs = []
for cls in total_images:
    obj = cls.split("___")[0]
    if obj not in objs:
        objs.append(obj)

num_objs = len(objs)
print(f"Número de Recicláveis: {num_objs} categorias")
print("Tipos de Reciclávieis: ")
for i, obj in enumerate(objs):
    print(f"{i+1}. {obj}")
# Out:
# Número de Recicláveis: 30 categorias
# Tipos de Reciclávieis:
# 1. aerosol_cans
# 2. aluminum_food_cans
# 3. aluminum_soda_cans
# 4. cardboard_boxes
# 5. cardboard_packaging
# 6. clothing
# 7. coffee_grounds
# 8. disposable_plastic_cutlery
# 9. eggshells
# 10. food_waste
# 11. glass_beverage_bottles
# 12. glass_cosmetic_containers
# 13. glass_food_jars
# 14. magazines
# 15. newspaper
# 16. office_paper
# 17. paper_cups
# 18. plastic_cup_lids
# 19. plastic_detergent_bottles
# 20. plastic_food_containers
# 21. plastic_shopping_bags
# 22. plastic_soda_bottles
# 23. plastic_straws
# 24. plastic_trash_bags
# 25. plastic_water_bottles
# 26. shoes
# 27. steel_food_cans
# 28. styrofoam_cups
# 29. styrofoam_food_containers
# 30. tea_bags

# %%
#Número de Imagens por Classe

df_images = pd.DataFrame(all_images, columns=['img_dir', 'img_corrupted', 'img_hash', 'image_format', 'width', 'height', 'channels', 'class'])

category_counts = df_images['class'].value_counts().reset_index()
category_counts.columns = ['class', 'count']

# Adicionar rótulos e título
plt.figure(figsize=(12, 6))
sns.barplot(x='class', y='count',data=category_counts)
plt.xticks(rotation=90)
plt.title('Quantidade de Imagens em cada Categoria')
plt.ylabel('Quantidade de Imagens')
plt.xlabel('Categorias')
plt.show()

# %% [markdown]
# ## 7. Verificar a Presença de Duplicatas

# %%
#Quantidade de imagens duplicatas
df_images['img_hash'].duplicated().sum()
# Out:
# 5149

# %%
#Imagens duplicatas
df_duplicated = df_images[df_images['img_hash'].duplicated()]
df_duplicated
# Out:
#                                                  img_dir  img_corrupted  \
# 30     ./recyclable-and-household-waste-classificatio...          False
# 31     ./recyclable-and-household-waste-classificatio...          False
# 32     ./recyclable-and-household-waste-classificatio...          False
# 34     ./recyclable-and-household-waste-classificatio...          False
# 35     ./recyclable-and-household-waste-classificatio...          False
# ...                                                  ...            ...
# 14991  ./recyclable-and-household-waste-classificatio...          False
# 14995  ./recyclable-and-household-waste-classificatio...          False
# 14996  ./recyclable-and-household-waste-classificatio...          False
# 14997  ./recyclable-and-household-waste-classificatio...          False
# 14998  ./recyclable-and-household-waste-classificatio...          False
#
#                img_hash image_format  width  height  channels  \
# 30     8fd99442d743c693          png    256     256         3
# 31     bc92c363c3249f69          png    256     256         3
# 32     bdc68239c9b62dc2          png    256     256         3
# 34     8fd99442d743c693          png    256     256         3
# 35     d2fc6d91748901ee          png    256     256         3
# ...                 ...          ...    ...     ...       ...
# 14991  8fe3b08cc9769869          png    256     256         3
# 14995  bed89491d62fc303          png    256     256         3
# 14996  c5f3a009dba6079b          png    256     256         3
# 14997  851feaf0f081b85e          png    256     256         3
# 14998  ee8791704a8d3fe0          png    256     256         3
#
#                        class
# 30     plastic_shopping_bags
# 31     plastic_shopping_bags
# 32     plastic_shopping_bags
# 34     plastic_shopping_bags
# 35     plastic_shopping_bags
# ...                      ...
# 14991        steel_food_cans
# 14995        steel_food_cans
# 14996        steel_food_cans
# 14997        steel_food_cans
# 14998        steel_food_cans
#
# [5149 rows x 8 columns]

# %%
duplicated_images = {}
for i in range(df_duplicated.shape[0]):
  hash_duplicated = df_duplicated.iloc[i]['img_hash']
  duplicated = df_images[df_images['img_hash'] == hash_duplicated]["img_dir"].values
  duplicated_images[str(hash_duplicated)] = duplicated.tolist()

# %%
#Imagens correspondentes a cada imagem duplicada
duplicated_images
# Out:
# {'8fd99442d743c693': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_1.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_34.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_116.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_83.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_223.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_35.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_trash_bags/default/Image_54.png'],
#  'bc92c363c3249f69': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_138.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_71.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_197.png'],
#  'bdc68239c9b62dc2': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_181.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_97.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_24.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_78.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_66.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_123.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_82.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_55.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_246.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_100.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_68.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_201.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_84.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_41.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_110.png'],
#  'd2fc6d91748901ee': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_243.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_151.png'],
#  'c23227be3e9c1c3c': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_156.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_96.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_85.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_132.png'],
#  'e99a9c318633659e': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_21.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_42.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_75.png'],
#  '9bc4cc4cb321d55b': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_98.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_236.png'],
#  '9ee6e1199c2027cf': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_77.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_172.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_152.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_8.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_63.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_113.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_127.png'],
#  'e89a8534c76692e7': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_248.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_92.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_87.png'],
#  '8cf1d32ec814e5d3': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_131.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_247.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_203.png'],
#  'fec4c416b21fc85a': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_99.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_36.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_2.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_60.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_82.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_133.png'],
#  'ebb5f6928a5a8948': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_60.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_191.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_105.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_184.png'],
#  '87522dd372875a2d': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_167.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_65.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_165.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_188.png'],
#  'ea4c91bbcaa48b3a': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_111.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_149.png'],
#  'd3fcad82a232933c': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_14.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_163.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_86.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_89.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_104.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_81.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_53.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_122.png'],
#  'bf99f84685611bc2': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_52.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_62.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_230.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_247.png'],
#  'e8949136e763872d': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_101.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_33.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_168.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_183.png'],
#  '8f489637f1b49076': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_225.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_193.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_193.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_162.png'],
#  'c62644d6bf1f90b4': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_39.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_130.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_86.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_140.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_246.png'],
#  'c273117c6dc3817d': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_113.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_147.png'],
#  'c7c569ca72983596': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_29.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_44.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_109.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_62.png'],
#  'f40c8be288957f5a': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_32.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_132.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_33.png'],
#  'e0c7cb69c969cc68': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_49.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_28.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_69.png'],
#  '8d5a3d4af2858f68': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_135.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_188.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_154.png'],
#  '8c36f329cdcdd016': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_54.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_17.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_38.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_107.png'],
#  'cb3834d961937366': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_23.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_84.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_124.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_74.png'],
#  'bccdc33292369363': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_26.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_103.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_208.png'],
#  'c1313ec62ec336cb': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_235.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_110.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_211.png'],
#  'bc66e19c9f1998c1': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_7.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_159.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_126.png'],
#  '9638e9c6a6b91cc6': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_160.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_50.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_229.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_54.png'],
#  'c23626be3c9c3c3c': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_5.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_93.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_55.png'],
#  'ea95852ad66093eb': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_114.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_190.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_136.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_237.png'],
#  'eaa56ec22d9bc192': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_22.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_57.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_134.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_66.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_trash_bags/default/Image_207.png'],
#  '9b8ce473e649a916': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_10.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_52.png'],
#  'fec4c416923fc85a': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_136.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_98.png'],
#  'bcc3c31cc92ccb99': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_185.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_239.png'],
#  'abb0c483c6e78e87': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_161.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_91.png'],
#  'd24a8db1aea6631d': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_47.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_1.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_112.png'],
#  'bd9cc84bb53252b1': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_107.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_199.png'],
#  'ef8cddd5807ad202': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_139.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_176.png'],
#  'd03b3cf00b648ff2': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_12.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_120.png'],
#  'f886ce99c39d9033': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_127.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_175.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_101.png'],
#  'ebc4d630c51eb163': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_59.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_138.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_238.png'],
#  'b93cc6e78780989e': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_204.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_181.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_189.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_152.png'],
#  '8ff8b824954ace78': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_222.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_97.png'],
#  'aff0905ae66da390': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_170.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_151.png'],
#  'bcc8c23dc339c333': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_63.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_90.png'],
#  '807d3ba66689d387': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_15.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_164.png'],
#  'b15bcfa470c3253c': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_25.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_180.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_224.png'],
#  '903fefc0bc81d728': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_106.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_118.png'],
#  'ea4a8d6a9d699865': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_13.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_77.png'],
#  'f83797cc8cc7e180': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_141.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_139.png'],
#  'ea4e696b916a8d68': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_171.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_78.png'],
#  'e1d99866c69cc666': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_51.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_96.png'],
#  'aed8f4f8842f8c07': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_43.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_49.png'],
#  '999be664981c3793': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_20.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_206.png'],
#  'e5cccf309a639866': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_83.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_131.png'],
#  '8ae9b574d80bc197': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_79.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_236.png'],
#  'c43dbfe0e143a19c': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_128.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_14.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_119.png'],
#  '94386f6639a760d6': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_118.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_195.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_46.png'],
#  'ebe39654250c9e33': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_137.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_94.png'],
#  '83837b23238b6bab': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_9.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_111.png'],
#  'e4939b6ce6c33892': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_64.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_225.png'],
#  'ad1ec6d0c663c867': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_94.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_129.png'],
#  '87c96c2b598cccb3': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_58.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_40.png'],
#  '90cee7319ecee190': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_202.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_85.png'],
#  'e9cc8e833ac33b86': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_81.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_99.png'],
#  'fb839151a373332a': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_169.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_92.png'],
#  'aa12f53a95f195e0': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_150.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_226.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_240.png'],
#  'a4c9ca36b31976ca': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_21.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_220.png'],
#  '85e62292d3917fa9': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_224.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_198.png'],
#  'ee31e16e938687c4': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_16.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_67.png'],
#  'c341bbbed434816b': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_166.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_73.png'],
#  'afc4803b9939dd29': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_134.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_150.png'],
#  '96d28361f90ddc0f': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_4.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_56.png'],
#  'cff538843c812d9d': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_220.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_191.png'],
#  'b0c9cf328e669b26': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_68.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_79.png'],
#  'fbc2d42aad259455': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_186.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_146.png'],
#  'e37656143a8d2cad': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_143.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_115.png'],
#  '93323c24e5cfe598': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_249.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_205.png'],
#  'eb94364b966c9863': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_90.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_65.png'],
#  'abc4d44ad06ada67': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_129.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_149.png'],
#  '9e8d4b7031cb7619': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_165.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_158.png'],
#  'e4968b6994b46ad6': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_40.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_194.png'],
#  'becfc1300f8370ce': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_88.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_177.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_155.png'],
#  'ec9ec333c3699c28': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_56.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_163.png'],
#  'e992c5389d393963': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_176.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_106.png'],
#  '81bf3e0d6e4c6a62': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_158.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_185.png'],
#  '87c73167786c6958': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_180.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_241.png'],
#  '8632f845f8cbb722': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_76.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_168.png'],
#  'c0fa9ecca123c59d': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_31.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_157.png'],
#  'bab4b148b5b26933': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_61.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_87.png'],
#  'fb31b1989466e646': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_48.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_161.png'],
#  '86ce786d99996436': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_11.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_89.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_221.png'],
#  'be4bd1b483624b39': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_6.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_130.png'],
#  'f4148bea80157f5e': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_123.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_11.png'],
#  'e9a68152d6a91e9b': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_119.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_64.png'],
#  '9967ec90b688b3ca': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_143.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_187.png'],
#  'b6c4d8c3c2d99936': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_178.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_104.png'],
#  'ebb59452936a816b': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_30.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_210.png'],
#  'e4948b6b14b46bce': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_122.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_59.png'],
#  'cab6a38999d9954c': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_37.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_202.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_70.png'],
#  '8796782d78c9783c': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_80.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_160.png'],
#  'c13ebec0cb1f14b4': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_233.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_204.png'],
#  'c28ca773f83ca692': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_121.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_17.png'],
#  'e9946a98e732966a': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_102.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_105.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_trash_bags/default/Image_159.png'],
#  '86dae126bc2d96b8': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_250.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_148.png'],
#  'afc8d037f3ec0cc0': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_61.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_6.png'],
#  'e999c632c6669666': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_3.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_72.png'],
#  'b41fcfcac0e058f8': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_91.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_93.png'],
#  'd8d4b72981e47cd8': ['./recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/default/Image_27.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_shopping_bags/real_world/Image_57.png'],
#  'acc2d33de0c62dd2': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_164.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_182.png'],
#  'e79a87998c99cc64': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_25.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_49.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_36.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_28.png'],
#  'ba6e6dc16c866992': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_5.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_54.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_8.png'],
#  'bfc5c23ca41aa51b': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_244.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_131.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_107.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_220.png'],
#  'daaa77c6c807e055': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_37.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_14.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_63.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_110.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_38.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_21.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_213.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_119.png'],
#  'eb4a9548d2adc3b4': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_21.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_94.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_61.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_88.png'],
#  'da0cedc3922fe116': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_1.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_36.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_63.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_4.png'],
#  '9ee1e10a805fcba7': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_47.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_61.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_22.png'],
#  'eb37b79494c890d2': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_8.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_65.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_20.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_159.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_water_bottles/default/Image_100.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_water_bottles/default/Image_82.png',
#   './recyclable-and-household-waste-classification/images/images/plastic_soda_bottles/default/Image_30.png'],
#  'e8dc8761836793c6': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_100.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_86.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_79.png'],
#  'aec0911fc63fc278': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_38.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_45.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_7.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_78.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_12.png'],
#  'ebd428f318879c27': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_134.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_130.png'],
#  'cfb0b04f4fb07a30': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_216.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_147.png'],
#  'b223633333333367': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_48.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_44.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_32.png'],
#  '93ea4b8ccc33cc33': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_80.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_70.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_120.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_54.png'],
#  'b3cececc3888cc99': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_31.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_50.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_66.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_112.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_152.png'],
#  'e61a369926993bcc': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_237.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_178.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_192.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_137.png'],
#  'b0d3c696e64c9b2c': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_12.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_15.png'],
#  'bb983cb29692d2c3': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_66.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_52.png'],
#  'bf996b3163349831': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_112.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_25.png'],
#  'c7c0fc26814bfc71': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_249.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_186.png'],
#  'b3cccc31cc33cc33': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_53.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_60.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_76.png'],
#  'afaf4647ae54a850': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_173.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_222.png'],
#  'bfcfb034a49092cb': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_90.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_98.png'],
#  'd7aba954a6d16388': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_108.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_184.png'],
#  '934cecb3b2b193c4': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_82.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_91.png'],
#  'bd96c029bee884ce': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_136.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_1.png'],
#  'af91d02e2fd1d02e': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_96.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_199.png'],
#  'e6c69399cc1ccc33': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_74.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_176.png'],
#  'e699996599619966': ['./recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/default/Image_35.png',
#   './recyclable-and-household-waste-classification/images/images/glass_beverage_bottles/real_world/Image_95.png'],
# ...
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_128.png'],
#  'dbd2791be439601c': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_60.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_32.png'],
#  'b81ec7c4c7c1c4f1': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_23.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_88.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_165.png'],
#  'd44eae3091cb4e4f': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_19.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_62.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_50.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_4.png'],
#  'ed5a929592b592a5': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_53.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_232.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_139.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_215.png'],
#  '85277a70f41e9bd0': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_213.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_33.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_154.png'],
#  '99f071190bbdd4c3': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_189.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_45.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_127.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_203.png'],
#  'df5ff16029ad2150': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_151.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_113.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_179.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_168.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_145.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_148.png'],
#  '99e3721922b9d5ca': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_114.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_11.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_160.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_55.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_96.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_44.png'],
#  'eb5a9690949594bd': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_116.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_28.png'],
#  'd944371b329e668d': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_102.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_217.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_121.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_48.png'],
#  'bccfc3f0c230c63c': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_25.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_105.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_65.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_105.png'],
#  'b13ccecccec4c6c4': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_82.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_3.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_151.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_49.png'],
#  '99f2730927b55389': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_224.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_133.png'],
#  'b84ec7c1c7f19630': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_58.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_57.png'],
#  'e0bd42bd42a752a7': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_176.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_126.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_202.png'],
#  'e5399ac798869b26': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_42.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_15.png'],
#  'd04baf34f290e369': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_134.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_25.png'],
#  'edcb92b492249b6c': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_30.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_214.png'],
#  'b8cfc67463699834': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_118.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_222.png'],
#  'b84ec7ece1e0e0f0': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_184.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_98.png'],
#  'b12ccec39b33392c': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_29.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_184.png'],
#  '90667e59cec8d1e2': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_247.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_199.png'],
#  'ef93307c306c338d': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_96.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_26.png'],
#  'cb0394b4fcfcc10b': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_236.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_176.png'],
#  'ca85b56a4a95b56a': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_49.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_95.png'],
#  'e696399339863996': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_175.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_20.png'],
#  'e62d9bc399c29992': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_215.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_9.png'],
#  'c9483c97e2e2e65a': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_121.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_39.png'],
#  'ed4b92b493b491e4': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_70.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_136.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_123.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_185.png'],
#  'e4399a839bc69b86': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_100.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_156.png'],
#  'e89e9591a5a9ac39': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_228.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_90.png'],
#  'ce93e93e38186d4c': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_173.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_24.png'],
#  'fa0785291cd2f173': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_47.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_164.png'],
#  'c13b42a487d26ded': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_141.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_37.png'],
#  'edc3989e65379424': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_186.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_235.png'],
#  'e91ecdd2e4d99281': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_124.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_134.png'],
#  '8b836c34337d6c36': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_16.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_47.png'],
#  'cf9224cf24cd694d': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_138.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_153.png'],
#  'cec3709239cb6c4e': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_188.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_144.png'],
#  '8ee321be21bf309a': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_221.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_244.png'],
#  'bf078198c272d9cd': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_132.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_38.png'],
#  '9b07bca3b45ac558': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_66.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_21.png'],
#  '90a9d7562916abd6': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_145.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_180.png'],
#  'b04fc3c0e73436bc': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_89.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_18.png'],
#  'd483ab7c9e933423': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_110.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_118.png'],
#  'c490bf25e36a8597': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_210.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_182.png'],
#  'b80ec7c9c7e9e0e0': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_1.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_78.png'],
#  'bc93936dc21fc11c': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_7.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_58.png'],
#  'd4daab2174d65319': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_216.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_66.png'],
#  'e4699bc39bc49b84': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_196.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_174.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_166.png'],
#  'f91686697992636c': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_234.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_236.png'],
#  'd2f06d2b2f2b283a': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_17.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_14.png'],
#  'ce93e83e38586d4c': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_22.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_94.png'],
#  'e5499a93929693b6': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_79.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_172.png'],
#  'ed5b569a92999690': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_86.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_111.png'],
#  'acf4f1d8d101ce0f': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_27.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_85.png'],
#  'b03dcfc6d831384d': ['./recyclable-and-household-waste-classification/images/images/styrofoam_cups/default/Image_164.png',
#   './recyclable-and-household-waste-classification/images/images/styrofoam_cups/real_world/Image_238.png'],
#  ...}

# %%
image1 = cv2.imread('./recyclable-and-household-waste-classification/images/images/paper_cups/default/Image_138.png')
image2 = cv2.imread('./recyclable-and-household-waste-classification/images/images/paper_cups/default/Image_83.png')

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Converter de BGR (formato OpenCV) para RGB (formato Matplotlib)
image1_rgb = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2_rgb = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# Mostrar a primeira imagem
axes[0].imshow(image1_rgb)
axes[0].axis('off')  # Remove os eixos
axes[0].set_title('Imagem 1')

# Mostrar a segunda imagem
axes[1].imshow(image2_rgb)
axes[1].axis('off')  # Remove os eixos
axes[1].set_title('Imagem 2')

# Exibir as imagens
plt.show()
